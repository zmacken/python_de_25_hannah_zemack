# %%
from vector import Vector

#vector with coordinates 2 and 5
v1= Vector(2,5)
v2 = Vector(-1,1)
v1, v2
# Out:
# (Vector(2.0, 5.0), Vector(-1.0, 1.0))

# %%
print(f'{len(v1) =}')
print(f'{v1 + v2 =}')
# Out:
# len(v1) =2
# v1 + v2 =Vector(1.0, 6.0)

# %% [markdown]
# assert will be used in automatical testing

# %%
X=5

assert x
